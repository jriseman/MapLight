# %%
import pandas as pd
df = pd.read_csv('cand/2018_cand_0.csv')
df.shape
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,25,47,52,53,54,55,56,59,69,71,73,74,75,76,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (500000, 81)

# %%
#df.iloc[0:25,62:]
#df.info()
df.head()
# Out:
#   TransactionTypeCode                                    TransactionType  \
# 0                  15  Contribution to political committees (other th...
# 1                 15E  Earmarked contributions to political committee...
# 2                 15E  Earmarked contributions to political committee...
# 3                 15E  Earmarked contributions to political committee...
# 4                 15E  Earmarked contributions to political committee...
#
#    ElectionCycle  ReportingCommitteeMLID ReportingCommitteeFECID  \
# 0           2018                 6291728               C00326801
# 1           2018                 6291728               C00326801
# 2           2018                 6291728               C00326801
# 3           2018                 6291728               C00326801
# 4           2018                 6291728               C00326801
#
#      ReportingCommitteeName ReportingCommitteeNameNormalized  \
# 0  TAMMY BALDWIN FOR SENATE         TAMMY BALDWIN FOR SENATE
# ...

# %%
df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']].tail(200)
# Out:
#        RecipientCandidateNameNormalized RecipientCommitteeType  \
# 499800                    Tammy Baldwin                 Senate
# 499801                    Tammy Baldwin                 Senate
# 499802                    Tammy Baldwin                 Senate
# 499803                    Tammy Baldwin                 Senate
# 499804                    Tammy Baldwin                 Senate
# 499805                    Tammy Baldwin                 Senate
# 499806                    Tammy Baldwin                 Senate
# 499807                    Tammy Baldwin                 Senate
# 499808                    Tammy Baldwin                 Senate
# 499809                    Tammy Baldwin                 Senate
# 499810                    Tammy Baldwin                 Senate
# 499811                    Tammy Baldwin                 Senate
# 499812                    Tammy Baldwin                 Senate
# 499813                    Tammy Baldwin                 Senate
# ...

# %%
df_0 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_0
# Out:
#        RecipientCandidateNameNormalized RecipientCommitteeType  \
# 0                        Mark R Meadows                  House
# 1                  Matthew A Cartwright                  House
# 2                        Gerry Connolly                  House
# 3                       Elijah Cummings                  House
# 4                         Stephen Lynch                  House
# 5                Karen Christine Handel                  House
# 6                         Samuel Graves                  House
# 7                       Emanuel Cleaver                  House
# 8                         Kevin W Yoder                  House
# 9                         Samuel Graves                  House
# 10                 Matthew A Cartwright                  House
# 11                          Jason Smith                  House
# 12                         Robert Casey                 Senate
# 13                       Mark R Meadows                  House
# ...

# %%
import numpy as np
df = pd.read_csv('cand/2018_cand_1.csv')
df_1 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_1.index = np.arange(500000, len(df_1) + 500000)
df_1
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (25,42,52,61,62,63,64,65,66,67,68,69,71,73,74,75,76,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        RecipientCandidateNameNormalized RecipientCommitteeType  \
# 500000                    Tammy Baldwin                 Senate
# 500001                    Tammy Baldwin                 Senate
# 500002                    Tammy Baldwin                 Senate
# 500003                    Tammy Baldwin                 Senate
# 500004                    Tammy Baldwin                 Senate
# 500005                    Tammy Baldwin                 Senate
# 500006                    Tammy Baldwin                 Senate
# 500007                    Tammy Baldwin                 Senate
# 500008                    Tammy Baldwin                 Senate
# ...

# %%
frames = [df_0, df_1]
result = pd.concat(frames)
result
# Out:
#        ReportingCommitteeNameNormalized TransactionDate  TransactionAmount  \
# 0                    HALLMARK CARDS PAC      2017-02-24               2500
# 1                    HALLMARK CARDS PAC      2017-02-24               1000
# 2                    HALLMARK CARDS PAC      2017-02-24               2500
# 3                    HALLMARK CARDS PAC      2017-02-24               2500
# 4                    HALLMARK CARDS PAC      2017-02-24               2500
# 5                    HALLMARK CARDS PAC      2017-02-24               2500
# 6                    HALLMARK CARDS PAC      2017-02-24               2500
# 7                    HALLMARK CARDS PAC      2017-03-10               2000
# 8                    HALLMARK CARDS PAC      2017-03-10               2500
# 9                    HALLMARK CARDS PAC      2017-09-15               1000
# 10                   HALLMARK CARDS PAC      2017-09-15               1000
# ...

# %%
df = pd.read_csv('cand/2018_cand_2.csv')
df_2 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_2.index = np.arange(1000000, len(df_2) + 1000000)
df_2
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 1000000                       Jon Tester                 Senate
# 1000001                       Jon Tester                 Senate
# 1000002                       Jon Tester                 Senate
# 1000003                       Jon Tester                 Senate
# 1000004                       Jon Tester                 Senate
# 1000005                       Jon Tester                 Senate
# 1000006                       Jon Tester                 Senate
# 1000007                       Jon Tester                 Senate
# 1000008                       Jon Tester                 Senate
# 1000009                       Jon Tester                 Senate
# 1000010                       Jon Tester                 Senate
# 1000011                       Jon Tester                 Senate
# 1000012                       Jon Tester                 Senate
# 1000013                       Jon Tester                 Senate
# ...

# %%
df = pd.read_csv('cand/2018_cand_3.csv')
df_3 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_3.index = np.arange(1500000, len(df_3) + 1500000)
df_3
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 1500000              Garland Andy" Barr"                  House
# 1500001              Garland Andy" Barr"                  House
# 1500002              Garland Andy" Barr"                  House
# 1500003              Garland Andy" Barr"                  House
# 1500004              Garland Andy" Barr"                  House
# 1500005              Garland Andy" Barr"                  House
# 1500006              Garland Andy" Barr"                  House
# 1500007              Garland Andy" Barr"                  House
# 1500008              Garland Andy" Barr"                  House
# 1500009              Garland Andy" Barr"                  House
# 1500010              Garland Andy" Barr"                  House
# 1500011              Garland Andy" Barr"                  House
# 1500012              Garland Andy" Barr"                  House
# 1500013              Garland Andy" Barr"                  House
# ...

# %%
df = pd.read_csv('cand/2018_cand_4.csv')
df_4 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_4.index = np.arange(2000000, len(df_4) + 2000000)
df_4
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 2000000           Robert Beto" O'rourke"                 Senate
# 2000001           Robert Beto" O'rourke"                 Senate
# 2000002           Robert Beto" O'rourke"                 Senate
# 2000003           Robert Beto" O'rourke"                 Senate
# 2000004           Robert Beto" O'rourke"                 Senate
# 2000005           Robert Beto" O'rourke"                 Senate
# 2000006           Robert Beto" O'rourke"                 Senate
# 2000007           Robert Beto" O'rourke"                 Senate
# 2000008           Robert Beto" O'rourke"                 Senate
# 2000009           Robert Beto" O'rourke"                 Senate
# 2000010           Robert Beto" O'rourke"                 Senate
# 2000011           Robert Beto" O'rourke"                 Senate
# 2000012           Robert Beto" O'rourke"                 Senate
# 2000013           Robert Beto" O'rourke"                 Senate
# ...

# %%
frames = [df_0, df_1, df_2, df_3, df_4]
result = pd.concat(frames)
result
# Out:
#         ReportingCommitteeNameNormalized TransactionDate  TransactionAmount  \
# 0                     HALLMARK CARDS PAC      2017-02-24               2500
# 1                     HALLMARK CARDS PAC      2017-02-24               1000
# 2                     HALLMARK CARDS PAC      2017-02-24               2500
# 3                     HALLMARK CARDS PAC      2017-02-24               2500
# 4                     HALLMARK CARDS PAC      2017-02-24               2500
# 5                     HALLMARK CARDS PAC      2017-02-24               2500
# 6                     HALLMARK CARDS PAC      2017-02-24               2500
# 7                     HALLMARK CARDS PAC      2017-03-10               2000
# 8                     HALLMARK CARDS PAC      2017-03-10               2500
# 9                     HALLMARK CARDS PAC      2017-09-15               1000
# 10                    HALLMARK CARDS PAC      2017-09-15               1000
# ...

# %%
df = pd.read_csv('cand/2018_cand_5.csv')
df_5 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_5.index = np.arange(2500000, len(df_5) + 2500000)
df_5
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 2500000              Bradley Mark Walker                  House
# 2500001              Bradley Mark Walker                  House
# 2500002              Bradley Mark Walker                  House
# 2500003              Bradley Mark Walker                  House
# 2500004              Bradley Mark Walker                  House
# 2500005              Bradley Mark Walker                  House
# 2500006              Bradley Mark Walker                  House
# 2500007              Bradley Mark Walker                  House
# 2500008              Bradley Mark Walker                  House
# 2500009              Bradley Mark Walker                  House
# 2500010              Bradley Mark Walker                  House
# 2500011              Bradley Mark Walker                  House
# 2500012              Bradley Mark Walker                  House
# 2500013              Bradley Mark Walker                  House
# ...

# %%
df = pd.read_csv('cand/2018_cand_6.csv')
df_6 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_6.index = np.arange(3000000, len(df_6) + 3000000)
df_6
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 3000000               John Neely Kennedy                 Senate
# 3000001               John Neely Kennedy                 Senate
# 3000002               John Neely Kennedy                 Senate
# 3000003               John Neely Kennedy                 Senate
# 3000004               John Neely Kennedy                 Senate
# 3000005               John Neely Kennedy                 Senate
# 3000006               John Neely Kennedy                 Senate
# 3000007               John Neely Kennedy                 Senate
# 3000008               John Neely Kennedy                 Senate
# 3000009               John Neely Kennedy                 Senate
# 3000010               John Neely Kennedy                 Senate
# 3000011               John Neely Kennedy                 Senate
# 3000012               John Neely Kennedy                 Senate
# 3000013               John Neely Kennedy                 Senate
# ...

# %%
df = pd.read_csv('cand/2018_cand_7.csv')
df_7 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_7.index = np.arange(3500000, len(df_7) + 3500000)
df_7
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 3500000                      Josh Harder                  House
# 3500001                      Josh Harder                  House
# 3500002                      Josh Harder                  House
# 3500003                      Josh Harder                  House
# 3500004                      Josh Harder                  House
# 3500005                      Josh Harder                  House
# 3500006                      Josh Harder                  House
# 3500007                      Josh Harder                  House
# 3500008                      Josh Harder                  House
# 3500009                      Josh Harder                  House
# 3500010                      Josh Harder                  House
# 3500011                      Josh Harder                  House
# 3500012                      Josh Harder                  House
# 3500013                      Josh Harder                  House
# ...

# %%
df = pd.read_csv('cand/2018_cand_8.csv')
df_8 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_8.index = np.arange(4000000, len(df_8) + 4000000)
df_8
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 4000000                     Pete Stauber                  House
# 4000001                     Pete Stauber                  House
# 4000002                     Pete Stauber                  House
# 4000003                     Pete Stauber                  House
# 4000004                     Pete Stauber                  House
# 4000005                     Pete Stauber                  House
# 4000006                     Pete Stauber                  House
# 4000007                     Pete Stauber                  House
# 4000008                     Pete Stauber                  House
# 4000009                     Pete Stauber                  House
# 4000010                     Pete Stauber                  House
# 4000011                     Pete Stauber                  House
# 4000012                     Pete Stauber                  House
# 4000013                     Pete Stauber                  House
# ...

# %%
df = pd.read_csv('cand/2018_cand_9.csv')
df_9 = df[['RecipientCandidateNameNormalized','RecipientCommitteeType','DonorNameNormalized','DonorOrganization',
    'DonorCommitteeNameNormalized','DonorEntityTypeCode', 'DonorEntityType','DonorOccupationNormalized',
    'TransactionDate','TransactionAmount','RecipientCandidateParty','RecipientCandidateICO']]
df_9.index = np.arange(4500000, len(df_9) + 4500000)
df_9
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,8,25,50,51,52,53,54,55,56,59,61,62,63,64,65,66,67,68,69,71,73,74,75,76,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 4500000                    Cresent Hardy                  House
# 4500001                    Cresent Hardy                  House
# 4500002                    Cresent Hardy                  House
# 4500003                    Cresent Hardy                  House
# 4500004                    Cresent Hardy                  House
# 4500005                    Cresent Hardy                  House
# 4500006                    Cresent Hardy                  House
# 4500007                    Cresent Hardy                  House
# 4500008                    Cresent Hardy                  House
# ...

# %%
frames = [df_0, df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9]
df_comp18 = pd.concat(frames)
df_comp18
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 0                         Mark R Meadows                  House
# 1                   Matthew A Cartwright                  House
# 2                         Gerry Connolly                  House
# 3                        Elijah Cummings                  House
# 4                          Stephen Lynch                  House
# 5                 Karen Christine Handel                  House
# 6                          Samuel Graves                  House
# 7                        Emanuel Cleaver                  House
# 8                          Kevin W Yoder                  House
# 9                          Samuel Graves                  House
# 10                  Matthew A Cartwright                  House
# 11                           Jason Smith                  House
# 12                          Robert Casey                 Senate
# 13                        Mark R Meadows                  House
# ...

# %%
df_comp18.to_csv('df_comp18.csv')
