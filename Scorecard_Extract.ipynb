# %%
#import pandas as pd
#import tabula
#df2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")
#import PyPDF2
#pfr = PyPDF2.PdfFileReader(open('2018_LCV_Scorecard.pdf', "rb"))
#pg4 = pfr.getPage(14)
#df = tabula.read_pdf('2018_LCV_Scorecard.pdf', pages = '14', multiple_tables = True)
#TABULE NOT WORKING - SEEMS TO BE A JAVA CONFLICT WITH ANACONDA

# %%
import pandas as pd
df = pd.read_csv('df_comp12.csv')
df
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Unnamed: 0 RecipientCandidateNameNormalized RecipientCommitteeType  \
# 0                 0                   Richard A Berg                 Senate
# 1                 1                       David Camp                  House
# 2                 2                     John Shimkus                  House
# 3                 3                Lynn Westmoreland                  House
# 4                 4                 Charles Boustany                  House
# 5                 5                      Josh Mandel                 Senate
# 6                 6                    Henry Johnson                  House
# 7                 7                       Jim Cooper                  House
# ...

# %%
df = pd.read_csv('cand/2012_cand_0.csv')
df[['RecipientCandidateOfficeState','RecipientCandidateParty','RecipientCandidateOffice','RecipientCandidateOfficeState']].nunique()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (25,35,42,47,53,54,55,56,59,69,71,73,74,75,76,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# RecipientCandidateOfficeState    57
# RecipientCandidateParty          12
# RecipientCandidateOffice          3
# RecipientCandidateOfficeState    57
# dtype: int64

# %%
df_cand = df[['RecipientCandidateOffice','RecipientCandidateOfficeState','RecipientCandidateNameNormalized','RecipientCandidateParty','RecipientCandidateICO']]

# %%
df_cand = df_cand.sort_values(['RecipientCandidateOffice','RecipientCandidateOfficeState','RecipientCandidateNameNormalized'],ascending=True)

# %%
df_pols = df_cand.drop_duplicates()

# %%
df_pols
# Out:
#        RecipientCandidateOffice RecipientCandidateOfficeState  \
# 707                       House                            AK
# 1806                      House                            AK
# 16376                     House                            AL
# 6624                      House                            AL
# 32121                     House                            AL
# 27264                     House                            AL
# 21383                     House                            AL
# 79105                     House                            AL
# 342                       House                            AL
# 34060                     House                            AL
# 343                       House                            AL
# 344                       House                            AL
# 346                       House                            AL
# 17332                     House                            AL
# ...

# %%
df_pols.to_excel('pols_list12.xlsx')

# %%
df = pd.read_csv('df_comp16.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0 RecipientCandidateNameNormalized RecipientCommitteeType  \
# 0           0             W Blaine Luetkemeyer                  House
# 1           1                   Jason Chaffetz                  House
# 2           2                   Gerry Connolly                  House
# 3           3                    Kevin W Yoder                  House
# 4           4                  Emanuel Cleaver                  House
#
#   DonorNameNormalized DonorOrganization DonorCommitteeNameNormalized  \
# 0  HALLMARK CARDS PAC    Hallmark Cards           HALLMARK CARDS PAC
# 1  HALLMARK CARDS PAC    Hallmark Cards           HALLMARK CARDS PAC
# 2  HALLMARK CARDS PAC    Hallmark Cards           HALLMARK CARDS PAC
# 3  HALLMARK CARDS PAC    Hallmark Cards           HALLMARK CARDS PAC
# 4  HALLMARK CARDS PAC    Hallmark Cards           HALLMARK CARDS PAC
#
#    DonorEntityTypeCode DonorEntityType DonorOccupationNormalized  \
# ...

# %%
df['RecipientCandidateNameNormalized'].isna().sum()
# Out:
# 11

# %%
df['RecipientCandidateNameNormalized'] = df['RecipientCandidateNameNormalized'].fillna('none')

# %%
df[df['RecipientCandidateNameNormalized'].str.contains('McCain', case=False)]
# Out:
#          Unnamed: 0 RecipientCandidateNameNormalized RecipientCommitteeType  \
# 2746           2746                      John Mccain                 Senate
# 4353           4353                      John Mccain                 Senate
# 4354           4354                      John Mccain                 Senate
# 4552           4552                      John Mccain                 Senate
# 7724           7724                      John Mccain                 Senate
# 7744           7744                      John Mccain                 Senate
# 8354           8354                      John Mccain                 Senate
# 8429           8429                      John Mccain                 Senate
# 8807           8807                      John Mccain                 Senate
# 9689           9689                      John Mccain                 Senate
# 10080         10080                      John Mccain                 Senate
# ...

# %%
df_senate = pd.read_excel('pols_list_senate.xlsx')
df_senate
# Out:
#     RecipientCandidateOffice RecipientCandidateOfficeState  \
# 0                     Senate                            AK
# 1                     Senate                            AK
# 2                     Senate                            AL
# 3                     Senate                            AL
# 4                     Senate                            AR
# 5                     Senate                            AR
# 6                     Senate                            AZ
# 7                     Senate                            AZ
# 8                     Senate                            CA
# 9                     Senate                            CA
# 10                    Senate                            CO
# 11                    Senate                            CO
# 12                    Senate                            CT
# 13                    Senate                            CT
# 14                    Senate                            DE
# ...

# %%
# importing required modules 
import PyPDF2  

# creating a pdf file object 
pdfFileObj = open('2018_LCV_Scorecard.pdf', 'rb') 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 

text = ""
# creating a pdf reader object 

for i in range(pdfReader.numPages):
    text += pdfReader.getPage(i).extractText()
	
print(text[66800:69800])

# closing the pdf file object 
pdfFileObj.close()
# Out:
# ays, and
# circumvents bedrock environmental laws. ˛is amendment also included a short-term continu
# -ing resolution to fund the government through February 8 and emergency disaster relief fund
# -ing. On December 20, the House approved the Frelinghuysen amendment by a vote of 217-185
# (House roll call vote 472).
# NO IS THE PRO-ENVIRONMENT VOTE.
#  ˛e Senate took no action on
# this legislation.
# 30 scorecard.lcv.org | 2018 National Environmental Scorecard · LCV
# ALABAMA
# 1Byrne
# R000
# ˜˜˜˜˜˜˜˜˜˜˜˜˜
# ˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜
# 2Roby
# R634
# ˜˜˜˜˜˜˜˜˜˜
# %˜˜
# ˜˜˜˜˜
# ?˜˜˜˜˜˜˜˜
# %˜˜˜˜˜
# ?˜3Rogers, M.
# R316
# ˜˜˜˜˜˜
# %˜˜˜˜˜˜
# ˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜
# 4Aderholt
# R003
# ˜˜˜˜˜˜˜˜˜˜˜˜˜
# ˜?˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜
# 5Brooks, M.
# R20139
# ˜˜˜˜˜˜
# %˜˜˜˜˜
# %˜˜˜˜˜˜˜˜˜
# %%%%
# ˜˜˜˜
# %˜˜˜˜
# 6Palmer
# R001
# ˜˜˜˜˜˜˜˜˜˜˜˜˜
# ˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜˜
# 7Sewell
# ˜D718179˜%?˜˜
# %%%%
# ????
# %%%%
# ?%%%%%%%%%%%%%%
# ˜%%
# ALASKA
# ALYoung DonR638
# ˜˜˜˜˜˜˜˜˜˜
# %˜˜
# ˜˜˜˜˜
# ...
