# %%
import pandas as pd
df = pd.read_csv('nra-grades.csv')
df.head(100)
# Out:
#    state    body_type district_or_office  year     race  \
# 0     AK  State House         District 1  2012  Primary
# 1     AK  State House         District 1  2014  General
# 2     AK  State House         District 1  2012  General
# 3     AK  State House         District 1  2012  Primary
# 4     AK  State House         District 1  2014  Primary
# 5     AK  State House         District 1  2010  General
# 6     AK  State House         District 1  2014  Primary
# 7     AK  State House         District 1  2016  General
# 8     AK  State House         District 1  2014  General
# 9     AK  State House         District 1  2012  General
# 10    AK  State House         District 1  2010  General
# 11    AK  State House         District 1  2012  Primary
# 12    AK  State House         District 1  2012  Primary
# 13    AK  State House        District 10  2012  General
# 14    AK  State House        District 10  2010  General
# 15    AK  State House        District 10  2016  General
# ...
