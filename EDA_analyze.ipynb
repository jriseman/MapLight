# %%
import pandas as pd
df = pd.read_csv('df_comp18.csv')
df.shape
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (4675975, 13)

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4675975 entries, 0 to 4675974
# Data columns (total 12 columns):
# RecipientCandidateNameNormalized    object
# RecipientCommitteeType              object
# DonorNameNormalized                 object
# DonorOrganization                   object
# DonorCommitteeNameNormalized        object
# DonorEntityTypeCode                 int64
# DonorEntityType                     object
# DonorOccupationNormalized           object
# TransactionDate                     object
# TransactionAmount                   float64
# RecipientCandidateParty             object
# RecipientCandidateICO               object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 428.1+ MB

# %%
df['TransactionDate'].isnull()
#df['TransactionDate'] = df['TransactionDate'].astype("datetime64")
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 4675945    False
# 4675946    False
# 4675947    False
# 4675948    False
# 4675949    False
# 4675950    False
# 4675951    False
# 4675952    False
# 4675953    False
# 4675954    False
# 4675955    False
# 4675956    False
# 4675957    False
# 4675958    False
# 4675959    False
# 4675960    False
# 4675961    False
# 4675962    False
# 4675963    False
# 4675964    False
# 4675965    False
# ...

# %%
df.info()

# %%
df.tail()
# Out:
#          Unnamed: 0 RecipientCandidateNameNormalized RecipientCommitteeType  \
# 4675970     4675970                 Sean Colin Frame                  House
# 4675971     4675971          Mr. Neil Conrad Parrott                  House
# 4675972     4675972             Keith Allen Pottratz                 Senate
# 4675973     4675973                   Shlomo Nizahon                  House
# 4675974     4675974                    Julian Castro           Presidential
#
#                                        DonorNameNormalized  \
# 4675970  Unitemized contributions 2018-10-01 to 2018-12-31
# 4675971  Unitemized contributions 2018-11-07 to 2018-12-31
# 4675972  Unitemized contributions 2018-11-01 to 2018-12-31
# 4675973  Unitemized contributions 2018-10-01 to 2018-12-31
# 4675974  Unitemized contributions 2018-12-11 to 2018-12-31
#
#                 DonorOrganization DonorCommitteeNameNormalized  \
# 4675970  Unitemized contributions                          NaN
# ...

# %%
df[295000:3000000]
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 295000                     Sherrod Brown                 Senate
# 295001                     Sherrod Brown                 Senate
# 295002                     Sherrod Brown                 Senate
# 295003                     Sherrod Brown                 Senate
# 295004                     Sherrod Brown                 Senate
# 295005                     Sherrod Brown                 Senate
# 295006                     Sherrod Brown                 Senate
# 295007                     Sherrod Brown                 Senate
# 295008                     Sherrod Brown                 Senate
# 295009                     Sherrod Brown                 Senate
# 295010                     Sherrod Brown                 Senate
# 295011                     Sherrod Brown                 Senate
# 295012                     Sherrod Brown                 Senate
# 295013                     Sherrod Brown                 Senate
# ...

# %%
df['RecipientCandidateNameNormalized'].nunique()
# Out:
# 2887

# %%
df['RecipientCommitteeType'].nunique()
#Senate, House, Presidential
# Out:
# 3

# %%
df['DonorNameNormalized'].nunique()
# Out:
# 987963

# %%
df['DonorOrganization'].nunique()
# Out:
# 446329

# %%
df['DonorCommitteeNameNormalized'].nunique()
# Out:
# 4396

# %%
df['DonorEntityTypeCode'].nunique()
# Out:
# 8

# %%
df['DonorEntityType'].nunique()
# Out:
# 8

# %%
df['DonorOccupationNormalized'].nunique()
# Out:
# 83148

# %%
df['TransactionDate'].sort_values(ascending=True, inplace=False, kind='quicksort')
# Out:
# 4614604    0000-00-00
# 4426425    0000-00-00
# 2264888    0000-00-00
# 4226535    0000-00-00
# 4426423    0000-00-00
# 4226536    0000-00-00
# 4226555    0000-00-00
# 4505729    0000-00-00
# 4505730    0000-00-00
# 4658682    0000-00-00
# 4427648    0000-00-00
# 4658680    0000-00-00
# 4614605    0000-00-00
# 748586     0000-00-00
# 405664     0000-00-00
# 405533     0000-00-00
# 3804322    0000-00-00
# 4614620    0000-00-00
# 405532     0000-00-00
# 405528     0000-00-00
# 4614603    0000-00-00
# 4658673    0000-00-00
# 4427655    0000-00-00
# 4426424    0000-00-00
# 4662111    0000-00-00
# 4599997    0000-00-00
# 4654006    0000-00-00
# 111455     0000-00-00
# 111454     0000-00-00
# 4654007    0000-00-00
#               ...
# 3025229    2018-12-31
# 958748     2018-12-31
# 2572797    2019-01-01
# 2895044    2019-01-07
# 3775742    2019-01-16
# 3775741    2019-01-16
# 3694106    2019-03-29
# 3942468    2019-03-29
# 3390174    2019-03-29
# 3994950    2019-03-29
# ...

# %%
df['TransactionAmount'].max()
# Out:
# 17787376.11

# %%
df['TransactionAmount'].min()
# Out:
# -500000.0

# %%
df['RecipientCandidateParty'].nunique()
# Out:
# 19

# %%
df['RecipientCandidateICO'].nunique()
# Out:
# 3

# %%
#df['TransactionDate'].hist(bins=15)

# %%
df_sample = df.sample(1000)
df_sample.tail(100)
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 4100601               Lauren A Underwood                  House
# 3899939                   Levi Tillemann                  House
# 1293244                 Claire Mccaskill                 Senate
# 2541743                   Matt Rosendale                 Senate
# 8187                        Lou Barletta                 Senate
# 2840911                     Donald Trump           Presidential
# 2383115                   Kyrsten Sinema                 Senate
# 3731120                     Patrick Ryan                  House
# 1713664           Rafael Edward Ted Cruz                 Senate
# 3289501                  Antonio Delgado                  House
# 1092188                Alan Mark Grayson                  House
# 923036                      Peter Roskam                  House
# 4202414                      Leah Vukmir                 Senate
# 1273121                 Claire Mccaskill                 Senate
# ...

# %%
min(df_sample['TransactionDate'])
#df_sample['TransactionDate'] = df_sample['TransactionDate'].astype("datetime64")
# Out:
# '0000-00-00'

# %%
df_sample['TransactionDate'].hist(bins=15)

# %%
df[['DonorCommitteeNameNormalized']].count()
# Out:
# DonorCommitteeNameNormalized    2724102
# dtype: int64

# %%
df[['DonorOrganization']].count()
# Out:
# DonorOrganization    4675798
# dtype: int64

# %%
df[['DonorNameNormalized']].count()
# Out:
# DonorNameNormalized    4674435
# dtype: int64

# %%
df['TransactionAmount'].mean()
# Out:
# 630.2455921150149

# %%
df.groupby('DonorCommitteeNameNormalized').count()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                                     TransactionAmount
# DonorCommitteeNameNormalized
# ACTBLUE                                                       2372889
# EMILY'S LIST                                                    11211
# SENATE CONSERVATIVES FUND                                        8112
# SWING LEFT                                                       7210
# VOTESANE PAC                                                     6262
# JSTREETPAC                                                       6029
# CLUB FOR GROWTH PAC                                              4882
# DEMOCRACY ENGINE, INC., PAC                                      4539
# IT STARTS TODAY                                                  4522
# LEAGUE OF CONSERVATION VOTERS ACTION FUND                        3040
# NATIONAL AIR TRAFFIC CONTROLLERS ASSOCIATION PAC                 2573
# LOCKHEED MARTIN CORPORATION EMPLOYEES' POLITICA...               2208
# ...

# %%
df.groupby('DonorCommitteeNameNormalized').sum()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                                     TransactionAmount
# DonorCommitteeNameNormalized
# ACTBLUE                                                   443913414.0
# EMILY'S LIST                                                5535567.0
# DEMOCRACY ENGINE, INC., PAC                                 4386959.0
# JSTREETPAC                                                  4232909.0
# VOTESANE PAC                                                4182372.0
# CLUB FOR GROWTH PAC                                         3489016.0
# NATIONAL BEER WHOLESALERS ASSOCIATION POLITICAL...          3376000.0
# NATIONAL ASSOCIATION OF REALTORS POLITICAL ACTI...          3369250.0
# LEAGUE OF CONSERVATION VOTERS ACTION FUND                   3068995.0
# AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (A...          2937000.0
# NATIONAL AIR TRAFFIC CONTROLLERS ASSOCIATION PAC            2713000.0
# SENATE CONSERVATIVES FUND                                   2658431.0
# ...

# %%
df.groupby('DonorOrganization').count()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                               TransactionAmount
# DonorOrganization
# Not Employed                                             861357
# Retired                                                  485740
# Self-Employed                                            485381
# Not Available                                            342140
# None                                                     208214
# Homemaker                                                 19872
# Unitemized contributions                                  13388
# Google                                                     8548
# Unknown                                                    8489
# United States Department of Defense                        7275
# Lowe's Companies, Inc.                                     4496
# .                                                          4443
# Harvard University                                         3856
# ...

# %%
df.groupby('DonorOrganization').sum()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                               TransactionAmount
# DonorOrganization
# Unitemized contributions                           5.164671e+08
# Self-Employed                                      2.374298e+08
# Retired                                            1.730371e+08
# Not Employed                                       1.556951e+08
# Not Available                                      8.825221e+07
# State of Florida                                   7.055148e+07
# None                                               5.675667e+07
# Homemaker                                          2.232973e+07
# Meyer Distributing                                 2.033213e+07
# Total Wine & More                                  1.768340e+07
# United States Senate                               1.720399e+07
# Silicon Ranch Corp                                 1.497191e+07
# Cisneros For Congress                              1.230276e+07
# ...
