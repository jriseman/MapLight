# %%
import pandas as pd
df_O = pd.read_csv('Donor_Org_Group_Merge_18.csv')
df_O[180:210]
# Out:
#                                      DonorOrganization  TransactionAmount  \
# 180               American Hotel & Lodging Association           939424.0
# 181                         Paloma Partners Management           939000.0
# 182                                      Quicken Loans           936959.0
# 183                           Brian Flynn for Congress           936762.0
# 184                      American College of Radiology           929100.0
# 185                                             Toyota           919499.0
# 186  Building Relationships in Diverse Geographic E...           914750.0
# 187                                  American Airlines           912186.0
# 188  National Association of Convenience Stores (NACS)           909525.0
# 189                        DaVita Health Care Partners           909425.0
# 190              American Physical Therapy Association           908245.0
# 191                                   John P. Joyce Md           906423.0
# ...

# %% [markdown]
#     DonorOrganization	        TransactionAmount	Count
# 0	Unitemized contributions	5.164671e+08	    13388
# 1	Self-Employed	            2.374298e+08    	485381
# 2	Retired	                    1.730371e+08    	485740
# 3	Not Employed	            1.556951e+08    	861357
# 4	Not Available	            8.825221e+07	    342140
# 5	State of Florida	        7.055148e+07    	722
# 6	None	                    5.675667e+07     	208214
# 7	Homemaker	                2.232973e+07    	19872
# 8	Meyer Distributing	        2.033213e+07    	41
# 9	Total Wine & More	        1.768340e+07    	113
# 10	United States Senate	    1.720399e+07    	744
# 11	Silicon Ranch Corp	        1.497191e+07    	89
# 12	Cisneros For Congress	    1.230276e+07	    33
# 13	Candidate	                9.703901e+06    	436
# 14	Unknown	                    6.127426e+06	    8489
# 15	The Gil & Jackie Cisneros F	5.650000e+06     	12
# 16	United States House of Repr	5.282785e+06    	1084
# 17	Brown Gibbons Lang & Comp	4.858928e+06    	91
# 18	Google	                    4.287930e+06    	8548
# 19	National Assn of Realtors	3.430650e+06    	1851
# 20	Natl Beer Wholesalers Assn	3.379450e+06    	1355
# 21	AT&T	                    3.313321e+06    	3414
# 22	Comcast	                    3.130945e+06    	2168
# 23	Deloitte	                3.025973e+06     	2160
# 24	Lockheed Martin	            3.011152e+06    	3767
# 25	Boeing	                    2.858364e+06	    3658

# %%
df_O[df_O['DonorOrganization'].str.contains('freeport mcmoran', case=False)]
# Out:
#                   DonorOrganization  TransactionAmount  Count
# 884  Freeport McMoRan Copper & Gold           250790.0    165

# %%
import pandas as pd
df_C = pd.read_csv('Donor_Commit_Group_Merge_18.csv')
df_C[0:60]
# Out:
#                          DonorCommitteeNameNormalized  TransactionAmount  \
# 0                                             ACTBLUE        443913414.0
# 1                                        EMILY'S LIST          5535567.0
# 2                         DEMOCRACY ENGINE, INC., PAC          4386959.0
# 3                                          JSTREETPAC          4232909.0
# 4                                        VOTESANE PAC          4182372.0
# 5                                 CLUB FOR GROWTH PAC          3489016.0
# 6   NATIONAL BEER WHOLESALERS ASSOCIATION POLITICA...          3376000.0
# 7   NATIONAL ASSOCIATION OF REALTORS POLITICAL ACT...          3369250.0
# 8           LEAGUE OF CONSERVATION VOTERS ACTION FUND          3068995.0
# 9   AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (...          2937000.0
# 10   NATIONAL AIR TRAFFIC CONTROLLERS ASSOCIATION PAC          2713000.0
# 11                          SENATE CONSERVATIVES FUND          2658431.0
# ...

# %%
df_C[df_C['DonorCommitteeNameNormalized'].str.contains('freeport', case=False)]
# Out:
#                           DonorCommitteeNameNormalized  TransactionAmount  \
# 935  FREEPORT-MCMORAN COPPER & GOLD INC. CITIZENSHI...           128500.0
#
#      Count
# 935     47

# %%
df_O.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542867 entries, 0 to 542866
# Data columns (total 3 columns):
# DonorOrganization    542867 non-null object
# TransactionAmount    542867 non-null float64
# Count                542867 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 12.4+ MB

# %%
df_C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4473 entries, 0 to 4472
# Data columns (total 3 columns):
# DonorCommitteeNameNormalized    4473 non-null object
# TransactionAmount               4473 non-null float64
# Count                           4473 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 104.9+ KB

# %%
df_C['TransactionAmount'].sum()
# Out:
# 510063246.0

# %%
df_C['Count'].sum()
# Out:
# 333277

# %%
df_O['TransactionAmount'].sum()
# Out:
# 3002613621.1800013

# %%
df_O['Count'].sum()
# Out:
# 2575448

# %%
df_O['TransactionAmount'].sum()/df_C['TransactionAmount'].sum()
# Out:
# 5.886747662622218

# %%
df_O['Count'].sum()/df_C['Count'].sum()
# Out:
# 7.727649972845411
