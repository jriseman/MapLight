# %%
import pandas as pd
df = pd.read_csv('df_comp18.csv')
df.shape
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (4675975, 13)

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4675975 entries, 0 to 4675974
# Data columns (total 12 columns):
# RecipientCandidateNameNormalized    object
# RecipientCommitteeType              object
# DonorNameNormalized                 object
# DonorOrganization                   object
# DonorCommitteeNameNormalized        object
# DonorEntityTypeCode                 int64
# DonorEntityType                     object
# DonorOccupationNormalized           object
# TransactionDate                     object
# TransactionAmount                   float64
# RecipientCandidateParty             object
# RecipientCandidateICO               object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 428.1+ MB

# %%
df[df['DonorCommitteeNameNormalized'].str.contains('crown', case=False)]
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 267427                    Daniel Webster                  House
# 267428                     Robin L Kelly                  House
# 267429                 Brian Fitzpatrick                  House
# 267430                   Brendan F Boyle                  House
# 267431                    Martha Mcsally                 Senate
# 1154473                     Robert Casey                 Senate
#
#                         DonorNameNormalized    DonorOrganization  \
# 267427   CROWN CORK & SEAL COMPANY INC. PAC  Crown Holdings Inc.
# 267428   CROWN CORK & SEAL COMPANY INC. PAC  Crown Holdings Inc.
# 267429   CROWN CORK & SEAL COMPANY INC. PAC  Crown Holdings Inc.
# 267430   CROWN CORK & SEAL COMPANY INC. PAC  Crown Holdings Inc.
# 267431   CROWN CORK & SEAL COMPANY INC. PAC  Crown Holdings Inc.
# 1154473       Crown Cork & Seal Company Pac  Crown Holdings Inc.
#
# ...

# %%
df['DonorOrganization'].isna().sum()
#.f['TransactionDate'] = df['TransactionDate'].astype("datetime64")
# Out:
# 177

# %%
df['DonorCommitteeNameNormalized'].isna().sum()
# Out:
# 1951873

# %%
df['DonorCommitteeNameNormalized'] = df['DonorCommitteeNameNormalized'].fillna('none')

# %%
df['DonorNameNormalized'] = df['DonorNameNormalized'].fillna('none')
df['DonorOrganization'] = df['DonorOrganization'].fillna('none')

# %%
df['DonorCommitteeNameNormalized'] = df['DonorCommitteeNameNormalized'].fillna('none')

# %%
df[df['DonorCommitteeNameNormalized'].str.match('ACTBLUE')]
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 63275                      Patrick Leahy                 Senate
# 63282                      Patrick Leahy                 Senate
# 63284                      Patrick Leahy                 Senate
# 63287                      Patrick Leahy                 Senate
# 63310                      Patrick Leahy                 Senate
# 63311                      Patrick Leahy                 Senate
# 63313                      Patrick Leahy                 Senate
# 63316                      Patrick Leahy                 Senate
# 63322                      Patrick Leahy                 Senate
# 63326                      Patrick Leahy                 Senate
# 63327                      Patrick Leahy                 Senate
# 63328                      Patrick Leahy                 Senate
# 63332                      Patrick Leahy                 Senate
# 63339                      Patrick Leahy                 Senate
# ...

# %%
df[df['DonorOrganization'].str.match('National Rifle')]
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 66791       William Steve Southerland Ii                  House
# 66792               John Timothy Griffin                  House
# 66793                      Raul Labrador                  House
# 66794                     Michael Mccaul                  House
# 66795               John Timothy Griffin                  House
# 66796                   Kristi Lynn Noem                  House
# 66797                   Richard B Nugent                  House
# 66798                        Martha Roby                  House
# 66799                        Martha Roby                  House
# 66800                      Raul Labrador                  House
# 66801                      Steve Fincher                  House
# 66802                       George Allen                 Senate
# 66803                   Marsha Blackburn                  House
# 66804                        Eric Cantor                  House
# ...

# %%
df.info()

# %%
df.head(200)
# Out:
#     RecipientCandidateNameNormalized RecipientCommitteeType  \
# 0                     Richard A Berg                 Senate
# 1                         David Camp                  House
# 2                       John Shimkus                  House
# 3                  Lynn Westmoreland                  House
# 4                   Charles Boustany                  House
# 5                        Josh Mandel                 Senate
# 6                      Henry Johnson                  House
# 7                         Jim Cooper                  House
# 8            Eric Alan Rick Crawford                  House
# 9                 Mrs. Diane L Black                  House
# 10           Mr Robert James Dold Jr                  House
# 11                   Donald Manzullo                  House
# 12                        Sean Duffy                  House
# 13                  Dennis Alan Ross                  House
# 14                Jefferson Sessions                 Senate
# ...

# %%
df[295000:300000]
# Out:
#        RecipientCandidateNameNormalized RecipientCommitteeType  \
# 295000                        Roy Blunt                 Senate
# 295001                        Roy Blunt                 Senate
# 295002                        Roy Blunt                 Senate
# 295003                        Roy Blunt                 Senate
# 295004                        Roy Blunt                 Senate
# 295005                        Roy Blunt                 Senate
# 295006                        Roy Blunt                 Senate
# 295007                        Roy Blunt                 Senate
# 295008                        Roy Blunt                 Senate
# 295009                        Roy Blunt                 Senate
# 295010                        Roy Blunt                 Senate
# 295011                        Roy Blunt                 Senate
# 295012                        Roy Blunt                 Senate
# 295013                        Roy Blunt                 Senate
# ...

# %%
df['RecipientCandidateNameNormalized'].nunique()
# Out:
# 2548

# %%
df['RecipientCommitteeType'].unique()
#Senate, House, Presidential
# Out:
# array(['Senate', 'House', 'Presidential', 'PAC - Nonqualified'],
#       dtype=object)

# %%
df['DonorNameNormalized'].nunique()
# Out:
# 1172229

# %%
df['DonorOrganization'].nunique()
# Out:
# 542867

# %%
df['DonorCommitteeNameNormalized'].nunique()
# Out:
# 4473

# %%
df['DonorEntityTypeCode'].nunique()
# Out:
# 8

# %%
df['DonorEntityType'].unique()
# Out:
# array([nan, 'Unknown', 'Individual', 'Organization', 'Candidate',
#        'Party Organization', 'Political Action Committee',
#        'Candidate Committee', 'Committee'], dtype=object)

# %%
df['DonorOccupationNormalized'].nunique()
# Out:
# 102674

# %%
df['TransactionDate'].sort_values(ascending=True, inplace=False, kind='quicksort')
# Out:
# 2362755    0000-00-00
# 76108      0000-00-00
# 1154714    0000-00-00
# 505233     0000-00-00
# 298438     0000-00-00
# 1068454    0000-00-00
# 8337517    0000-00-00
# 8071382    0000-00-00
# 1360422    0000-00-00
# 7288044    0000-00-00
# 1432792    0000-00-00
# 1406110    0000-00-00
# 2362756    0000-00-00
# 1231227    0000-00-00
# 838075     0000-00-00
# 2362752    0000-00-00
# 2362753    0000-00-00
# 2362754    0000-00-00
# 2362757    0000-00-00
# 2362751    0000-00-00
# 7307896    0000-00-00
# 8357886    0000-00-00
# 1412284    0000-00-00
# 8051029    0000-00-00
# 8051024    0000-00-00
# 7988165    0000-00-00
# 7988163    0000-00-00
# 504578     0000-00-00
# 2328844    0000-00-00
# 1412283    0000-00-00
#               ...
# 149372     2016-12-31
# 149355     2016-12-31
# 171772     2016-12-31
# 148195     2016-12-31
# 148188     2016-12-31
# 148183     2016-12-31
# 148110     2016-12-31
# 148151     2016-12-31
# 148153     2016-12-31
# 148165     2016-12-31
# ...

# %%
df['TransactionAmount'].max()
# Out:
# 33069327.61

# %%
df['TransactionAmount'].min()
# Out:
# -450000.0

# %%
df['RecipientCandidateParty'].nunique()
# Out:
# 18

# %%
df['RecipientCandidateICO'].nunique()
# Out:
# 3

# %%
#df['TransactionDate'].hist(bins=15)

# %%
df_sample = df.sample(1000)
df_sample.tail(100)
# Out:
#         RecipientCandidateNameNormalized RecipientCommitteeType  \
# 3306965            Katherine Lauren Hill                  House
# 375809                     Sherrod Brown                 Senate
# 2336516                   Heidi Heitkamp                 Senate
# 902600                      Doris Matsui                  House
# 4574905           Mr Mitt Willard Romney                 Senate
# 555830                 Janice Schakowsky                  House
# 2910111                  Pramila Jayapal                  House
# 2702456                       Al Franken                 Senate
# 4467294                   Martha Mcsally                 Senate
# 1150659                     Robert Casey                 Senate
# 3501349                      Josh Harder                  House
# 3035405                   Sara Hernandez                  House
# 2696781                       Al Franken                 Senate
# 4520273              Daniel Jay O'connor                  House
# ...

# %%
min(df_sample['TransactionDate'])
#df_sample['TransactionDate'] = df_sample['TransactionDate'].astype("datetime64")
# Out:
# '2016-12-21'

# %%
import numpy as np
df_sample['TransactionDate'].hist(bins=15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-774b5f3d97f0> in <module>
#       1 import numpy as np
# ----> 2 df_sample['TransactionDate'].hist(bins=15)
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2479         values = self.dropna().values
#    2480
# -> 2481         ax.hist(values, bins=bins, **kwds)
#    2482         ax.grid(grid)
#    2483         axes = np.array([ax])
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
df[['DonorCommitteeNameNormalized']].count()
# Out:
# DonorCommitteeNameNormalized    2054280
# dtype: int64

# %%
df[['DonorOrganization']].count()
# Out:
# DonorOrganization    8411713
# dtype: int64

# %%
df[['DonorNameNormalized']].count()
# Out:
# DonorNameNormalized    8410796
# dtype: int64

# %%
df['TransactionAmount'].mean()
# Out:
# 376.0183514549175

# %%
df.groupby('DonorCommitteeNameNormalized').count()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                                     TransactionAmount
# DonorCommitteeNameNormalized
# ACTBLUE                                                         34380
# EMILY'S LIST                                                     8426
# CLUB FOR GROWTH PAC                                              5487
# SENATE CONSERVATIVES FUND                                        3120
# NATIONAL ASSOCIATION OF REALTORS POLITICAL ACTI...               2074
# HONEYWELL INTERNATIONAL POLITICAL ACTION COMMITTEE               2031
# UNITED PARCEL SERVICE INC. PAC                                   1885
# LOCKHEED MARTIN CORPORATION EMPLOYEES' POLITICA...               1820
# VOTESANE PAC                                                     1810
# COUNCIL FOR A LIVABLE WORLD CANDIDATE FUND                       1771
# DEMOCRATIC CONGRESSIONAL CAMPAIGN COMMITTEE                      1687
# AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (A...               1659
# ...

# %%
df.groupby('DonorCommitteeNameNormalized').sum()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                                     TransactionAmount
# DonorCommitteeNameNormalized
# none                                                     1.944976e+09
# ACTBLUE                                                  4.439134e+08
# EMILY'S LIST                                             5.535567e+06
# DEMOCRACY ENGINE, INC., PAC                              4.386959e+06
# JSTREETPAC                                               4.232909e+06
# VOTESANE PAC                                             4.182372e+06
# CLUB FOR GROWTH PAC                                      3.489016e+06
# NATIONAL BEER WHOLESALERS ASSOCIATION POLITICAL...       3.376000e+06
# NATIONAL ASSOCIATION OF REALTORS POLITICAL ACTI...       3.369250e+06
# LEAGUE OF CONSERVATION VOTERS ACTION FUND                3.068995e+06
# AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (A...       2.937000e+06
# NATIONAL AIR TRAFFIC CONTROLLERS ASSOCIATION PAC         2.713000e+06
# ...

# %%
Donor_Commit_Group_Cnt_2012 = df.groupby('DonorCommitteeNameNormalized').count()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
Donor_Commit_Group_Sum_2012 = df.groupby('DonorCommitteeNameNormalized').sum()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
Donor_Commit_Group_Cnt_2012 = Donor_Commit_Group_Cnt_2012.rename(index=str, columns={"TransactionAmount": "Count"})

# %%
Donor_Commit_Group_Cnt_2012.head(60)
# Out:
#                                                     Count
# DonorCommitteeNameNormalized
# ACTBLUE                                             34380
# EMILY'S LIST                                         8426
# CLUB FOR GROWTH PAC                                  5487
# SENATE CONSERVATIVES FUND                            3120
# NATIONAL ASSOCIATION OF REALTORS POLITICAL ACTI...   2074
# HONEYWELL INTERNATIONAL POLITICAL ACTION COMMITTEE   2031
# UNITED PARCEL SERVICE INC. PAC                       1885
# LOCKHEED MARTIN CORPORATION EMPLOYEES' POLITICA...   1820
# VOTESANE PAC                                         1810
# COUNCIL FOR A LIVABLE WORLD CANDIDATE FUND           1771
# DEMOCRATIC CONGRESSIONAL CAMPAIGN COMMITTEE          1687
# AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (A...   1659
# AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)           1558
# JSTREETPAC                                           1541
# LEAGUE OF CONSERVATION VOTERS ACTION FUND            1512
# ...

# %%
Donor_Commit_Group_Sum_2012.head(60)
# Out:
#                                                     TransactionAmount
# DonorCommitteeNameNormalized
# ACTBLUE                                                    21807873.0
# SENATE CONSERVATIVES FUND                                   6887953.0
# CLUB FOR GROWTH PAC                                         4419449.0
# EMILY'S LIST                                                3815192.0
# NATIONAL ASSOCIATION OF REALTORS POLITICAL ACTI...          3639342.0
# NATIONAL BEER WHOLESALERS ASSOCIATION POLITICAL...          3352000.0
# HONEYWELL INTERNATIONAL POLITICAL ACTION COMMITTEE          3161389.0
# DEALERS ELECTION ACTION COMMITTEE OF THE NATION...          3054000.0
# INTERNATIONAL BROTHERHOOD OF ELECTRICAL WORKERS...          2753200.0
# ENGINEERS POLITICAL EDUCATION COMMITTEE (EPEC)/...          2618389.0
# AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)                  2588500.0
# AMERICAN ASSOCIATION FOR JUSTICE POLITICAL ACTI...          2490500.0
# ...

# %%
Donor_Commit_Group_Merge_2012 = Donor_Commit_Group_Sum_2012.merge(Donor_Commit_Group_Cnt_2012, 
                                                                  on = 'DonorCommitteeNameNormalized')
Donor_Commit_Group_Merge_2012.head(60)
# Out:
#                                                     TransactionAmount  Count
# DonorCommitteeNameNormalized
# ACTBLUE                                                    21807873.0  34380
# SENATE CONSERVATIVES FUND                                   6887953.0   3120
# CLUB FOR GROWTH PAC                                         4419449.0   5487
# EMILY'S LIST                                                3815192.0   8426
# NATIONAL ASSOCIATION OF REALTORS POLITICAL ACTI...          3639342.0   2074
# NATIONAL BEER WHOLESALERS ASSOCIATION POLITICAL...          3352000.0   1183
# HONEYWELL INTERNATIONAL POLITICAL ACTION COMMITTEE          3161389.0   2031
# DEALERS ELECTION ACTION COMMITTEE OF THE NATION...          3054000.0   1147
# INTERNATIONAL BROTHERHOOD OF ELECTRICAL WORKERS...          2753200.0    790
# ENGINEERS POLITICAL EDUCATION COMMITTEE (EPEC)/...          2618389.0    708
# AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)                  2588500.0   1558
# ...

# %%
df.groupby('DonorOrganization').count()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                      TransactionAmount
# DonorOrganization
# Self-Employed                                   289784
# Retired                                         270590
# Not Available                                    72114
# None                                             63104
# Not Employed                                     62579
# Unknown                                          56283
# Homemaker                                        47701
# Unitemized contributions                         11223
# United States Department of Defense               7005
# AT&T                                              3154
# Lockheed Martin                                   2952
# U.S. Government                                   2906
# Boeing                                            2842
# Microsoft                                         2835
# Wells Fargo                                       2701
# General Electric                                  2540
# ...

# %%
df.groupby('DonorOrganization').sum()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
# Out:
#                                         TransactionAmount
# DonorOrganization
# Unitemized contributions                     5.516443e+08
# Self-Employed                                2.660650e+08
# Retired                                      1.659847e+08
# Not Available                                6.806267e+07
# Dewhurst, David                              6.102890e+07
# Candidate                                    5.882219e+07
# Homemaker                                    5.715336e+07
# Unknown                                      4.585862e+07
# None                                         4.541976e+07
# Not Employed                                 3.611059e+07
# Sobhani, Rob                                 9.615205e+06
# Baron Equities                               9.439580e+06
# Leppert, Thomas C                            8.100000e+06
# Brunner For Senate                           7.997899e+06
# Obama Victory Fund 2012                      7.200000e+06
# ...

# %%
Donor_Org_Group_Cnt_2012 = df.groupby('DonorOrganization').count()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
Donor_Org_Group_Sum_2012 = df.groupby('DonorOrganization').sum()[['TransactionAmount']].sort_values(by = ['TransactionAmount'], 
                                                                                      ascending = False)
Donor_Org_Group_Cnt_2012 = Donor_Org_Group_Cnt_2012.rename(index=str, columns={"TransactionAmount": "Count"})

# %%
Donor_Org_Group_Cnt_2012.head(60)
# Out:
#                                                      Count
# DonorOrganization
# Self-Employed                                       289784
# Retired                                             270590
# Not Available                                        72114
# None                                                 63104
# Not Employed                                         62579
# Unknown                                              56283
# Homemaker                                            47701
# Unitemized contributions                             11223
# United States Department of Defense                   7005
# AT&T                                                  3154
# Lockheed Martin                                       2952
# U.S. Government                                       2906
# Boeing                                                2842
# Microsoft                                             2835
# Wells Fargo                                           2701
# ...

# %%
Donor_Org_Group_Merge_2012 = Donor_Org_Group_Sum_2012.merge(Donor_Org_Group_Cnt_2012, 
                                                                  on = 'DonorOrganization')
Donor_Org_Group_Merge_2012.head(60)
# Out:
#                                                     TransactionAmount   Count
# DonorOrganization
# Unitemized contributions                                 5.516443e+08   11223
# Self-Employed                                            2.660650e+08  289784
# Retired                                                  1.659847e+08  270590
# Not Available                                            6.806267e+07   72114
# Dewhurst, David                                          6.102890e+07      57
# Candidate                                                5.882219e+07     260
# Homemaker                                                5.715336e+07   47701
# Unknown                                                  4.585862e+07   56283
# None                                                     4.541976e+07   63104
# Not Employed                                             3.611059e+07   62579
# Sobhani, Rob                                             9.615205e+06      30
# ...

# %%
Donor_Org_Group_Merge_2012.to_csv('Donor_Org_Group_Merge_12.csv')
Donor_Commit_Group_Merge_2012.to_csv('Donor_Commit_Group_Merge_12.csv')
